# %% [markdown]
# <a href="https://colab.research.google.com/github/castillokarol1603-rgb/diagrama-de-flujo-de-tienda-en-linea/blob/main/DF_tienda_en_linea_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
compra=float(input("ingresa el total de la compra"))

if compra > 800:
   print("el envio es gratis")
   print("su total es:", compra)
else:
   costotal=compra + 150
   print("su total es:", costotal)

# %%
compra=float(input("ingresa el total de la compra"))

if compra > 800:
   print("el envio es gratis")
   print("su total es:", compra)
else:
   costotal=compra + 150
   print("su total es:", costotal)

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/castillokarol1603-rgb/diagrama-de-flujo-de-tienda-en-linea/refs/heads/main/Diagrama%20tienda%20en%20linea.png)
